# %%
DetPos =[
        [ 0 ,       0 , 0 ],
        [ 0 , -8.4497 , 0]]

SrcPos = [ 
    [ -2.4748 ,   2.4748  , 0.    ],
    [ -2.4748 ,  -2.4748  , 0.    ],
    [  2.4748 ,   2.4748  , 0.    ],
    [  2.4748 ,  -2.4748  , 0.    ],
    [ -2.4748 ,  -5.9748  , 0.    ],
    [ -2.4748 , -10.9245  , 0.    ],
    [  2.4748 ,  -5.9748  , 0.    ],
    [  2.4748 , -10.9245  , 0.    ] ]

SpatialUnit = 'cm'

# %%
MeasList = [ 
    [ 1 , 1 , 1 , 1 ],
    [ 2 , 1 , 1 , 1 ],
    [ 3 , 1 , 1 , 1 ],
    [ 4 , 1 , 1 , 1 ],
    [ 5 , 2 , 1 , 1 ],
    [ 6 , 2 , 1 , 1 ],
    [ 7 , 2 , 1 , 1 ],
    [ 8 , 2 , 1 , 1 ],
    [ 1 , 1 , 1 , 2 ],
    [ 2 , 1 , 1 , 2 ],
    [ 3 , 1 , 1 , 2 ],
    [ 4 , 1 , 1 , 2 ],
    [ 5 , 2 , 1 , 2 ],
    [ 6 , 2 , 1 , 2 ],
    [ 7 , 2 , 1 , 2 ],
    [ 8 , 2 , 1 , 2 ] ]

# %%
tabLSL  = [
    [1, 2], 
    [2, 4], 
    [3, 6], 
    [4, 8], 
    [5, 26], 
    [6, 28], 
    [7, 30], 
    [8, 32], 
    [9, 1], 
    [10, 3], 
    [11, 5], 
    [12, 7], 
    [13, 25], 
    [14, 27], 
    [15, 29],
    [16, 31]
]

labelChannel = [
    'Rx1-Tx1-HbO',
    'Rx1-Tx2-HbO',
    'Rx1-Tx3-HbO',
    'Rx1-Tx4-HbO',
    'Rx2-Tx5-HbO',
    'Rx2-Tx6-HbO',
    'Rx2-Tx7-HbO',
    'Rx2-Tx8-HbO',
    'Rx1-Tx1-HbR',
    'Rx1-Tx2-HbR',
    'Rx1-Tx3-HbR',
    'Rx1-Tx4-HbR',
    'Rx2-Tx5-HbR',
    'Rx2-Tx6-HbR',
    'Rx2-Tx7-HbR',
    'Rx2-Tx8-HbR'
]

labelChannelLite = [
    'Rx1-Tx1',
    'Rx1-Tx2',
    'Rx1-Tx3',
    'Rx1-Tx4',
    'Rx2-Tx5',
    'Rx2-Tx6',
    'Rx2-Tx7',
    'Rx2-Tx8'
    ]

labelChannelLiteLite = [
    'Rx1'
    'Rx1'
    'Rx1'
    'Rx1'
    'Rx2'
    'Rx2'
    'Rx2'
    'Rx2'
    ]

a = 0.01
